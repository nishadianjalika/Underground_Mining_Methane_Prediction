# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
original_train_data = pd.read_csv("../../extracted_data/training_data_full_with_columns.csv")
original_test_data = pd.read_csv("../../extracted_data/test_data_full_with_columns.csv")

train_label_path = '../../extracted_data/train_labels_full_with_columns.csv'
train_labels = pd.read_csv(train_label_path)

test_data = pd.read_csv("../../feature_extracted_data/test_features_01.csv")
test_labels = pd.read_csv("../../extracted_data/test_labels_full_with_columns.csv")

# %%
import matplotlib.pyplot as plt

# Example data from your previous message
train_class_counts = train_mm263.value_counts()
test_class_counts = test_mm263.value_counts()

# Calculate percentages for annotations
train_total = train_class_counts.sum()
test_total = test_class_counts.sum()
train_percentages = (train_class_counts / train_total * 100).round(2)
test_percentages = (test_class_counts / test_total * 100).round(2)

# Plotting the distributions for train and test dataset
fig, ax = plt.subplots(1, 2, figsize=(10, 8), sharey=True)

# Training data plot
ax[0].bar(train_class_counts.index, train_class_counts.values, color='blue')
ax[0].set_title('Training Dataset Class Distribution')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Count')
ax[0].set_xticks([0, 1])
ax[0].set_xticklabels(['Normal', 'Warning'])
# Annotating the training data bars
for i, count in enumerate(train_class_counts):
    ax[0].text(i, count, f'({train_percentages[i]}%)', ha='center', va='bottom')

# Testing data plot
ax[1].bar(test_class_counts.index, test_class_counts.values, color='green')
ax[1].set_title('Testing Dataset Class Distribution')
ax[1].set_xlabel('Class')
ax[1].set_xticks([0, 1])
ax[1].set_xticklabels(['Normal', 'Warning'])
# Annotating the testing data bars
for i, count in enumerate(test_class_counts):
    ax[1].text(i, count, f'({test_percentages[i]}%)', ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/ph/mqs9kl656hv6_7dcqk4stw900000gn/T/ipykernel_6449/2960121274.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[0].text(i, count, f'({train_percentages[i]}%)', ha='center', va='bottom')
# /var/folders/ph/mqs9kl656hv6_7dcqk4stw900000gn/T/ipykernel_6449/2960121274.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax[1].text(i, count, f'({test_percentages[i]}%)', ha='center', va='bottom')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Assuming the zeros_df DataFrame already contains the correct data

# Set the positions of the bars
bar_width = 0.35
index = np.arange(len(sensors))

# Plotting the proportions side by side
fig, ax = plt.subplots(figsize=(14, 8))
bar1 = ax.bar(index, zeros_df['Zero Proportion'], bar_width, label='Zero Values', color='orange')
bar2 = ax.bar(index + bar_width, zeros_df['Non-Zero Proportion'], bar_width, label='Non-Zero Values', color='green')

# Add some labels and a title
ax.set_xlabel('Sensors')
ax.set_ylabel('Proportion (%)')
ax.set_title('Proportion of Zero vs Non-Zero Values in Sensor Columns')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(sensors, rotation=45)
ax.legend()

# Layout
plt.tight_layout()
plt.show()
